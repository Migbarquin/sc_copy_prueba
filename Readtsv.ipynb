# %%
import pandas as pd
panglao = pd.read_csv('/home/miguelb/Documents/PhD/DATABASES/panglaodb/PanglaoDB.tsv', sep='\t')
# Out:
#      SRA accession SRS accession    Tissue origin of the sample  \
# 2        SRA605557    SRS2493625                Cd14+ monocytes
# 4        SRA711898    SRS3349280                         Tonsil
# 5        SRA553822    SRS2119548  Cultured embryonic stem cells
# 7        SRA605557    SRS2493626                Cd14+ monocytes
# 9        SRA608611    SRS2517317               Lung progenitors
# ...            ...           ...                            ...
# 1286     SRA867342    SRS4550173                        T cells
# 1295     SRA878024    SRS4660847                          Lungs
# 1296     SRA878024    SRS4660845                          Lungs
# 1299     SRA878024    SRS4660846                          Lungs
# 1301     SRA878024    SRS4660848                          Lungs
#
#      scRNA-seq protocol       Species Sequencing instrument  \
# 2          10x chromium  Homo sapiens   Illumina HiSeq 2500
# 4          10x chromium  Homo sapiens   Illumina HiSeq 2500
# ...

# %%
panglao.loc[panglao['Species'] == "Homo sapiens"]
# Out:
#      SRA accession SRS accession    Tissue origin of the sample  \
# 2        SRA605557    SRS2493625                Cd14+ monocytes
# 4        SRA711898    SRS3349280                         Tonsil
# 5        SRA553822    SRS2119548  Cultured embryonic stem cells
# 7        SRA605557    SRS2493626                Cd14+ monocytes
# 9        SRA608611    SRS2517317               Lung progenitors
# ...            ...           ...                            ...
# 1286     SRA867342    SRS4550173                        T cells
# 1295     SRA878024    SRS4660847                          Lungs
# 1296     SRA878024    SRS4660845                          Lungs
# 1299     SRA878024    SRS4660846                          Lungs
# 1301     SRA878024    SRS4660848                          Lungs
#
#      scRNA-seq protocol       Species Sequencing instrument  \
# 2          10x chromium  Homo sapiens   Illumina HiSeq 2500
# 4          10x chromium  Homo sapiens   Illumina HiSeq 2500
# ...
